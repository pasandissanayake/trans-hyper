# %%
import openml
import pandas as pd

DATASET_ID = 21

dataset = openml.datasets.get_dataset(DATASET_ID)

X, y, categorical_indicator, attribute_names = dataset.get_data(
    dataset_format="dataframe",
    target=dataset.default_target_attribute
)

print(X.shape, y.shape)
print("Categorical features:", sum(categorical_indicator))
# Out:
# (1728, 6) (1728,)
# Categorical features: 6

# %%
df = X.merge(y, left_index=True, right_index=True)
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df['class'].value_counts()
# Out:
# class
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
attribute_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety']

# %%
datasets_df = openml.datasets.list_datasets(output_format="dataframe")

# %%
datasets_df
# Out:
#          did                           name  version uploader  status format  \
# 2          2                         anneal        1        1  active   ARFF
# 3          3                       kr-vs-kp        1        1  active   ARFF
# 4          4                          labor        1        1  active   ARFF
# 5          5                     arrhythmia        1        1  active   ARFF
# 6          6                         letter        1        1  active   ARFF
# ...      ...                            ...      ...      ...     ...    ...
# 47143  47143  dummy_edit_test_dataset_ipynb        2    53508  active   arff
# 47144  47144  dummy_edit_test_dataset_ipynb        3    53508  active   arff
# 47145  47145  dummy_edit_test_dataset_ipynb        4    53508  active   arff
# 47146  47146  dummy_edit_test_dataset_ipynb        5    53508  active   arff
# 47147  47147  dummy_edit_test_dataset_ipynb        6    53508  active   arff
#
#        MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  \
# 2                  684.0                          7.0                8.0
# 3                 1669.0                          3.0             1527.0
# 4                   37.0                          3.0               20.0
# 5                  245.0                         13.0                2.0
# 6                  813.0                         26.0              734.0
# ...                  ...                          ...                ...
# 47143                NaN                          NaN                NaN
# 47144                NaN                          NaN                NaN
# 47145                NaN                          NaN                NaN
# 47146                NaN                          NaN                NaN
# 47147                NaN                          NaN                NaN
#
#        NumberOfClasses  NumberOfFeatures  NumberOfInstances  \
# 2                  5.0              39.0              898.0
# 3                  2.0              37.0             3196.0
# 4                  2.0              17.0               57.0
# 5                 13.0             280.0              452.0
# 6                 26.0              17.0            20000.0
# ...                ...               ...                ...
# 47143              0.0               2.0                3.0
# 47144              0.0               2.0                3.0
# 47145              0.0               2.0                3.0
# 47146              0.0               2.0                3.0
# 47147              0.0               2.0                3.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 2                                   898.0                22175.0
# 3                                     0.0                    0.0
# 4                                    56.0                  326.0
# 5                                   384.0                  408.0
# 6                                     0.0                    0.0
# ...                                   ...                    ...
# 47143                                 0.0                    0.0
# 47144                                 0.0                    0.0
# 47145                                 0.0                    0.0
# 47146                                 0.0                    0.0
# 47147                                 0.0                    0.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 2                          6.0                      33.0
# 3                          0.0                      37.0
# 4                          8.0                       9.0
# 5                        206.0                      74.0
# 6                         16.0                       1.0
# ...                        ...                       ...
# 47143                      2.0                       0.0
# 47144                      2.0                       0.0
# 47145                      2.0                       0.0
# 47146                      2.0                       0.0
# 47147                      2.0                       0.0
#
# [6377 rows x 16 columns]
