# %%
import torch
from tabpfn import TabPFNClassifier

# %%
classifier = TabPFNClassifier(n_estimators=1, fit_mode="batched", differentiable_input=False)
classifier._initialize_model_variables()
# Out:
# (2, Generator(PCG64) at 0x7F151BB2B5A0)

# %%
for name, params in classifier.model_.named_parameters():
    print(name, params.shape)
# Out:
# encoder.5.layer.weight torch.Size([192, 4])
# y_encoder.2.layer.weight torch.Size([192, 2])
# y_encoder.2.layer.bias torch.Size([192])
# transformer_encoder.layers.0.self_attn_between_features._w_out torch.Size([6, 32, 192])
# transformer_encoder.layers.0.self_attn_between_features._w_qkv torch.Size([3, 6, 32, 192])
# transformer_encoder.layers.0.self_attn_between_items._w_out torch.Size([6, 32, 192])
# transformer_encoder.layers.0.self_attn_between_items._w_qkv torch.Size([3, 6, 32, 192])
# transformer_encoder.layers.0.mlp.linear1.weight torch.Size([768, 192])
# transformer_encoder.layers.0.mlp.linear2.weight torch.Size([192, 768])
# transformer_encoder.layers.1.self_attn_between_features._w_out torch.Size([6, 32, 192])
# transformer_encoder.layers.1.self_attn_between_features._w_qkv torch.Size([3, 6, 32, 192])
# transformer_encoder.layers.1.self_attn_between_items._w_out torch.Size([6, 32, 192])
# ...
