# %%
# --- Cell 1: Imports ---
import yaml
from munch import Munch
from pathlib import Path

# Ensure yaml loader works safely
def yaml_load(path):
    with open(path, "r") as f:
        return yaml.safe_load(f)

def yaml_dump(data, path):
    with open(path, "w") as f:
        yaml.dump(data, f, sort_keys=False)

# %%
# --- Cell 2: Example list of config paths ---

# datasets = ["bank", "calhousing", "income"]
datasets = ["calhousing"]
n_examples = [8, 16, 32, 64]
config_paths = []

for ds in datasets:
    for n in n_examples:
        config_paths.append(f"./cfgs/pfn/n{n:0>2}/{ds}.yaml")
        # config_paths.append(f"./cfgs/pfn/depth/{ds}.yaml")

for path in config_paths:
    print(path)
# Out:
# ./cfgs/pfn/n08/calhousing.yaml
# ./cfgs/pfn/n16/calhousing.yaml
# ./cfgs/pfn/n32/calhousing.yaml
# ./cfgs/pfn/n64/calhousing.yaml

# %%
# --- Cell 3: Load configs as Munch objects ---
configs = {}

for path in config_paths:
    data = yaml_load(path)
    configs[path] = Munch.fromDict(data)

# Inspect one example
configs[config_paths[0]]
# Out:
# Munch({'name': 'tabpfn-calhousing', 'note': 'TabPFN hypernetwork with 8-shot calhousing dataset, without learning rate schedule', 'save_dir': './save/', 'eval_model': False, 'wandb_auth': 'wandb_auth.yaml', 'wandb_sweep_cfg': False, 'debug': False, 'debug_datasets': False, 'debug_hypernet': False, 'debug_hyponet': False, 'debug_trainer': False, 'hypernet': Munch({'name': 'tabpfn'}), 'hyponet': Munch({'model': 'mlp', 'in_dim': 0, 'out_dim': 2, 'hidden_dim': 10, 'depth': 4}), 'trainer': Munch({'name': 'tabpfn_trainer', 'batch_size': 1, 'n_workers': 1, 'max_epoch': 300, 'eval_epoch': 1, 'vis_epoch': 25, 'save_epoch': 500, 'optimizer': Munch({'name': 'adam', 'args': Munch({'lr': 0.0002, 'weight_decay': '1e-3'})})}), 'datasets': Munch({'data_root': './data/', 'n_shots': 4, 'n_queries': 4, 'train_ratio': 'None', 'test_ratio': 'None', 'train_size': 1, 'val_size': 1, 'test_size': 1, 'train_permutation': True, 'val_permutation': True, 'test_permutation': False, 'queries_same_as_shots': False, 'max_n_features': False, 'set_hyponet_indim': True, 'balanced': Munch({'train': True, 'val': True, 'test': False}), 'list_combine_train': ['calhousing'], 'list_combine_val': ['calhousing'], 'list_combine_test': ['calhousing']}), 'random_state': 0})

# %%
# --- Cell 4: Edit attributes programmatically ---
for path, cfg in configs.items():
    # cfg.random_state = 0
    # cfg.trainer.optimizer.args.lr = 2e-4
    cfg.trainer.optimizer.args.weight_decay = 1e-3
    # cfg.datasets.n_shots = 8
    # cfg.datasets.n_queries = 8
    # cfg.datasets.train_size = 2
    # cfg.datasets.queries_same_as_shots = True

# %%
# --- Cell 5: Save configs back ---
for path, cfg in configs.items():
    # Convert back to dict before dumping
    yaml_dump(cfg.toDict(), path)

print("✅ All configs updated and saved.")
# Out:
# ✅ All configs updated and saved.
