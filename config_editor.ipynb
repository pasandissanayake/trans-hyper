# %%
# --- Cell 1: Imports ---
import yaml
from munch import Munch
from pathlib import Path

# Ensure yaml loader works safely
def yaml_load(path):
    with open(path, "r") as f:
        return yaml.safe_load(f)

def yaml_dump(data, path):
    with open(path, "w") as f:
        yaml.dump(data, f, sort_keys=False)

# %%
# --- Cell 2: Example list of config paths ---

# datasets = ["bank", "calhousing", "income"]
datasets = ["bank"]
n_examples = [4, 8, 16, 32, 64]
config_paths = []

for ds in datasets:
    for n in n_examples:
        config_paths.append(f"./cfgs/pfn/n{n:0>2}/{ds}.yaml")
        # config_paths.append(f"./cfgs/pfn/depth/{ds}.yaml")

for path in config_paths:
    print(path)
# Out:
# ./cfgs/pfn/n04/bank.yaml
# ./cfgs/pfn/n08/bank.yaml
# ./cfgs/pfn/n16/bank.yaml
# ./cfgs/pfn/n32/bank.yaml
# ./cfgs/pfn/n64/bank.yaml

# %%
# --- Cell 3: Load configs as Munch objects ---
configs = {}

for path in config_paths:
    data = yaml_load(path)
    configs[path] = Munch.fromDict(data)

# Inspect one example
configs[config_paths[0]]
# Out:
# Munch({'name': 'tabpfn-bank', 'note': 'TabPFN hypernetwork with 4-shot bank dataset, without learning rate schedule', 'save_dir': './save/', 'eval_model': False, 'wandb_auth': 'wandb_auth.yaml', 'wandb_sweep_cfg': 'cfgs/sweeps/sweeptest.yaml', 'debug': True, 'debug_datasets': False, 'debug_hypernet': False, 'debug_hyponet': False, 'debug_trainer': False, 'hypernet': Munch({'name': 'tabpfn'}), 'hyponet': Munch({'model': 'mlp', 'in_dim': 0, 'out_dim': 2, 'hidden_dim': 10, 'depth': 4}), 'trainer': Munch({'name': 'tabpfn_trainer', 'batch_size': 1, 'n_workers': 1, 'max_epoch': 300, 'eval_epoch': 1, 'vis_epoch': 25, 'save_epoch': 500, 'optimizer': Munch({'name': 'adam', 'args': Munch({'lr': 0.0001})})}), 'datasets': Munch({'data_root': './data/', 'n_shots': 4, 'n_queries': 4, 'train_ratio': 'None', 'test_ratio': 'None', 'train_size': 1, 'val_size': 1, 'test_size': 1, 'train_permutation': True, 'val_permutation': True, 'test_permutation': False, 'queries_same_as_shots': True, 'max_n_features': False, 'set_hyponet_indim': True, 'balanced': Munch({'train': True, 'val': True, 'test': False}), 'list_combine_train': ['bank'], 'list_combine_val': ['bank'], 'list_combine_test': ['bank']}), 'random_state': True})

# %%
# --- Cell 4: Edit attributes programmatically ---
for path, cfg in configs.items():
    cfg.random_state = 26
    cfg.trainer.optimizer.args.lr = 2e-4
    cfg.hyponet.depth = 10
    cfg.wandb_sweep_cfg = False

# %%
# --- Cell 5: Save configs back ---
for path, cfg in configs.items():
    # Convert back to dict before dumping
    yaml_dump(cfg.toDict(), path)

print("✅ All configs updated and saved.")
# Out:
# ✅ All configs updated and saved.
