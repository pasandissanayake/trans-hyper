# %%
import pandas as pd

# %%
df = pd.read_csv("checkpoints/income/n64/results.csv")
summary = df.groupby("model")["roc_auc"].agg(["mean", "std"])
print(summary.round(2))
# Out:
#                     mean   std
# model
# LogisticRegression  0.84  0.03
# MLP                 0.79  0.04
# TabPFN              0.84  0.01
# XGBoost             0.81  0.01

# %%
df
# Out:
#                  model  seed   roc_auc
# 0   LogisticRegression    14  0.633413
# 1              XGBoost    14  0.500000
# 2               TabPFN    14  0.670892
# 3                  MLP    14  0.625191
# 4   LogisticRegression    26  0.393056
# 5              XGBoost    26  0.500000
# 6               TabPFN    26  0.587580
# 7                  MLP    26  0.475419
# 8   LogisticRegression    42  0.596470
# 9              XGBoost    42  0.500000
# 10              TabPFN    42  0.694123
# 11                 MLP    42  0.631766
# 12  LogisticRegression    58  0.481658
# 13             XGBoost    58  0.500000
# 14              TabPFN    58  0.583675
# 15                 MLP    58  0.497375
# 16  LogisticRegression    97  0.591903
# 17             XGBoost    97  0.500000
# 18              TabPFN    97  0.596079
# 19                 MLP    97  0.610690
